# %%
from skimage.io import imread, imshow
import os
import numpy

# %%
img1_path = os.path.join('..', '..', 'imgs', '134__zebra__0.9999949.jpg')
img2_path = os.path.join('..', '..', 'imgs', '4673__triumphal_arch__0.9999893.jpg')
img3_path = os.path.join('..', '..', 'imgs', '2380447__bullet_train__0.9999869.jpg')

# %%
img1 = imread(img1_path)
img2 = imread(img2_path)
img3 = imread(img3_path)

# %%
imshow(img1)

# %%
imshow(img2)

# %%
imshow(img3)

# %%
avgd_img = ((img1 + img2 + img3) // 3)

# %%
imshow(avgd_img)
